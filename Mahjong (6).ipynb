# %%
# 找所有可能雀頭
def findpair(x):
    tmp = []
    pair = []
    setx = set(x)
    for a in setx:
        for b in range(len(x)):
            if x[b] == a:
                tmp.append(a)
        if len(tmp) >= 2:
            pair.append(tmp[0])
            tmp.clear()
        else:
            tmp.clear()
    return pair

# %%
# 立直檢查
import copy
def checkrichi():
    global richi, player1, ron
    if not player1_call:
        for i in player1:
            if richi == 0:
                for a in tiles3:
                    tmp = copy.deepcopy(player1)
                    tmp.remove(i)
                    tmp.append(a)
                    checkron(tmp)
                    if ron == 1:
                        richi = 1
                        ron = 0
                        break

# %%
# 測最小牌能否找到順子
def checkflush(x):
    if x:
        if x[0] + 1 in x:
            tmp1 = x[0] + 1
            if x[0] + 2 in x:
                tmp2 = x[0] + 2
                x.remove(x[0])
                x.remove(tmp1)
                x.remove(tmp2)
    return x

# %%
# 測最小牌能否找到暗刻
def checktriple(x):
    global tri
    tmp = []
    for a in range(len(x)):
        if x[a] == x[0]:
            tmp.append(x[0])
    if len(tmp) >= 3:
        x.remove(tmp[0])
        x.remove(tmp[0])
        x.remove(tmp[0])
        tri = 1
    return x

# %%
# 測條子跟筒子是否會消光光
def roncheck(x):
    tri = 0
    win = 0
    count = 0
    while x:
        checktriple(x)
        if not x:
            win = 1
            return x
        if tri == 1:
            tri = 0
            continue
        checkflush(x)
        count += 1
        if not x:
            win = 1
            return x
        if count > 5:
            break
    if win == 0:
        return x

# %%
# 測是不是全部都暗刻，萬子跟字牌專用
def checktriple2(x):
    tmp = []
    for a in x:
        for b in range(len(x)):
            if a == x[b]:
                tmp.append(a)
        if len(tmp) == 3:
            x.remove(tmp[0])
            x.remove(tmp[0])
            x.remove(tmp[0])
        else:
            tmp.clear()
    return x

# %%
# 胡牌檢查
import copy
def checkron(x):
    global ron
    GG = 0
    check = []
    checkm = []
    checkp = []
    checks = []
    checky = []
    for i in x:
        check.append(int(i[1] // 4))
    for i in check:
        if i == 0:
            checkm.append(1)
        elif i == 1:
            checkm.append(9)
        elif 2 <= i <= 10:
            checkp.append(int(i - 1))
        elif 11 <= i <= 19:
            checks.append(int(i - 10))
        else:
            checky.append(int(i - 19))
    mpair = findpair(checkm)
    ppair = findpair(checkp)
    spair = findpair(checks)
    ypair = findpair(checky)
    for x in mpair:
        mtmp = copy.deepcopy(checkm)
        ptmp = copy.deepcopy(checkp)
        stmp = copy.deepcopy(checks)
        ytmp = copy.deepcopy(checky)
        mtmp.remove(x)
        mtmp.remove(x)
        checktriple2(mtmp)
        if mtmp:
            continue
        roncheck(ptmp)
        if ptmp:
            continue
        roncheck(stmp)
        if stmp:
            continue
        checktriple2(ytmp)
        if ytmp:
            continue
        else:
            ron = 1
            return ron
    for x in ppair:
        mtmp2 = copy.deepcopy(checkm)
        ptmp2 = copy.deepcopy(checkp)
        stmp2 = copy.deepcopy(checks)
        ytmp2 = copy.deepcopy(checky)
        ptmp2.remove(x)
        ptmp2.remove(x)
        checktriple2(mtmp2)
        if mtmp2:
            continue
        roncheck(ptmp2)
        if ptmp2:
            continue
        roncheck(stmp2)
        if stmp2:
            continue
        checktriple2(ytmp2)
        if ytmp2:
            continue
        else:
            ron = 1
            return ron
    for x in spair:
        mtmp3 = copy.deepcopy(checkm)
        ptmp3 = copy.deepcopy(checkp)
        stmp3 = copy.deepcopy(checks)
        ytmp3 = copy.deepcopy(checky)
        stmp3.remove(x)
        stmp3.remove(x)
        checktriple2(mtmp3)
        if mtmp3:
            continue
        roncheck(ptmp3)
        if ptmp3:
            continue
        roncheck(stmp3)
        if stmp3:
            continue
        checktriple2(ytmp3)
        if ytmp3:
            continue
        else:
            ron = 1
            return ron
    for x in ypair:
        mtmp4 = copy.deepcopy(checkm)
        ptmp4 = copy.deepcopy(checkp)
        stmp4 = copy.deepcopy(checks)
        ytmp4 = copy.deepcopy(checky)
        ytmp4.remove(x)
        ytmp4.remove(x)
        checktriple2(mtmp4)
        if mtmp4:
            continue
        roncheck(ptmp4)
        if ptmp4:
            continue
        roncheck(stmp4)
        if stmp4:
            continue
        checktriple2(ytmp4)
        if ytmp4:
            continue
        else:
            ron = 1
            return ron
    return ron

# %%
# 叫牌檢查
def checkponkan(x):
    global player1, c, call, player1_call
    tmp1 = 0
    lst1 = []
    a = x[1] // 4
    for i in range(len(player1)):
        if player1[i][1] // 4 == a:
            tmp1 += 1
            lst1.append(player1[i])
    if tmp1 == 2:
        print("This is your hand:\n" + str(player1))
        b = input("Do you want to pon " + str(x[0]) + "?")
        if b == "yes":
            call = 1
            player1_call.append(lst1[0])
            player1.remove(lst1[0])
            player1.remove(lst1[1])
            print("This is your hand:\n" + str(player1))
            e = input("Which one do you want to throw?")
            if 0 <= int(e) - 1 <= len(player1):
                d = player1.pop(int(e) - 1)
                player1river.append(d)
                return
    elif tmp1 == 3:
        print("This is your hand:\n" + str(player1))
        d = input("Do you want to pon or kan " + str(x[0]) + "?")
        if d == "kan":
            call = 1
            player1.remove(lst1[0])
            player1.remove(lst1[1])
            player1.remove(lst1[2])
            print("You draw this:" + str(tiles2[-1][0]))
            player1.append(tiles2[-1])
            player1 = sorted(player1, key=lambda tup:(tup[1]))
            tiles2.pop()
            print("This is your hand:\n" + str(player1))
            e = input("Which one do you want to throw?")
            if 0 <= int(e) - 1 <= len(player1):
                d = player1.pop(int(e) - 1)
                player1river.append(d)
                c += 1
                return
        elif d == "pon":
            call = 1
            player1_call.append(lst1[0])
            player1.remove(lst1[0])
            player1.remove(lst1[1])
            print("This is your hand:\n" + str(player1))
            e = input("Which one do you want to throw?")
            if 0 <= int(e) - 1 <= len(player1):
                d = player1.pop(int(e) - 1)
                player1river.append(d)
                return
    return

# %%
# 暗槓 or 加槓檢查
def checkkan(x):
    global player1, c, player1_call
    tmp1 = 0
    lst1 = []
    a = x[1] // 4
    b = x[0]
    if b in player1_call:
        d = input("Do you want to kan " + str(x[0]) + "?")
        if d == "yes":
            print("You draw this:" + str(tiles2[-1][0]))
            player1.remove(x)
            player1.append(tiles2[-1])
            player1 = sorted(player1, key=lambda tup:(tup[1]))
            tiles2.pop()
            print("This is your hand:\n" + str(player1))
            e = input("Which one do you want to throw?")
            if 0 <= int(e) - 1 <= len(player1):
                d = player1.pop(int(e) - 1)
                player1river.append(d)
                c += 1
                return
    for i in range(len(player1)):
        if player1[i][1] // 4 == a:
            tmp1 += 1
            lst1.append(player1[i])
    if tmp1 == 4:
        d = input("Do you want to kan " + str(x[0]) + "?")
        if d == "yes":
            player1.remove(lst1[0])
            player1.remove(lst1[1])
            player1.remove(lst1[2])
            player1.remove(lst1[3])
            print("You draw this:" + str(tiles2[-1][0]))
            player1.append(tiles2[-1])
            player1 = sorted(player1, key=lambda tup:(tup[1]))
            tiles2.pop()
            print("This is your hand:\n" + str(player1))
            e = input("Which one do you want to throw?")
            if 0 <= int(e) - 1 <= len(player1):
                d = player1.pop(int(e) - 1)
                player1river.append(d)
                c += 1
                return

# %%
# 拔北檢查
def checkpei():
    global player1, c, current_draw
    for i in range(len(player1)):
        if player1[i][1] // 4 == 23:
            print("This is your hand:\n" + str(player1))
            a = input("Do you want to pei?")
            if a == "yes":
                player1.remove(player1[i])
                print("You draw this:" + str(tiles2[-1][0]))
                player1.append(tiles2[-1])
                current_draw = tiles2[-1]
                player1 = sorted(player1, key=lambda tup:(tup[1]))
                tiles2.pop()
                c += 1

# %%
# 生成麻將牌
tiles = []
ping = []
souzu = []
onenine = []
c = 0
for y in range(4):
    onenine.append(('1m' + str(y+1), c))
    c += 1
for y in range(4):
    onenine.append(('9m' + str(y+1), c))
    c += 1
for x in range(9):
    for y in range(4):
        ping.append((str(x + 1) + 'p' + str(y+1), c))
        c += 1
for x in range(9):
    for y in range(4):
        souzu.append((str(x + 1) + 's' + str(y+1), c))
        c += 1
for y in range(4):
    onenine.append(('ton' + str(y+1), c))
    c += 1
for y in range(4):
    onenine.append(('nan' + str(y+1), c))
    c += 1
for y in range(4):
    onenine.append(('shia' + str(y+1), c))
    c += 1
for y in range(4):
    onenine.append(('pei' + str(y+1), c))
    c += 1
for y in range(4):
    onenine.append(('haku' + str(y+1), c))
    c += 1
for y in range(4):
    onenine.append(('hatsu' + str(y+1), c))
    c += 1
for y in range(4):
    onenine.append(('chun' + str(y+1), c))
    c += 1
tiles.append(ping)
tiles.append(souzu)
tiles.append(onenine)

# %%
# 整理成一個大list
tiles2 = []
tiles3 = []
for x in range(3):
    for y in range(len(tiles[x])):
        tiles2.append(tiles[x][y])
        tiles3.append(tiles[x][y])

# %%
# 洗牌
import random
random.shuffle(tiles2)

# %%
# 發牌，雖然不是正統發法
player1 = []
player2 = []
player3 = []
player1river = []
player2river = []
player3river = []
player1_call = []
c = 0
call = 0
ron = 0
richi = 0
current_draw = 0
for x in range(39):
    if x % 3 == 0:
        player1.append(tiles2[x])
        c += 1
    elif x % 3 == 1:
        player2.append(tiles2[x])
        c += 1
    else:
        player3.append(tiles2[x])
        c += 1
player1 = sorted(player1, key=lambda tup:(tup[1]))
player2 = sorted(player2, key=lambda tup:(tup[1]))
player3 = sorted(player3, key=lambda tup:(tup[1]))

# %%
# 摸牌 and 打牌
def drawandthrow1(c):
    global player1, ron, richi, current_draw
    print("You draw this:" + str(tiles2[c][0]))
    player1.append(tiles2[c])
    current_draw = tiles2[c]
    player1 = sorted(player1, key=lambda tup:(tup[1]))
    if richi == 2:
        checkpei()
        checkkan(tiles2[c])
        checkron(player1)
        if ron == 1:
            b = input("Do you want to tsumo?")
            if b == "yes":
                print("Tsumo!!!")
                c += 1000
                return c
        else:
            b = player1.remove(current_draw)
            player1river.append(b)
            c += 1
        return c
    else:
        checkpei()
        checkkan(tiles2[c])
        checkrichi()
        checkron(player1)
        if ron == 1:
            b = input("Do you want to tsumo?")
            if b == "yes":
                print("Tsumo!!!")
                c += 1000
                return c
            else:
                ron = 0
        if richi == 1:
            b = input("Do you want to richi?")
            if b == "yes":
                print("1P Richi!!!")
                richi = 2
            else:
                richi = 0
        print("This is your hand:\n" + str(player1))
        a = input("Which one do you want to throw?")
        if 0 <= int(a) - 1 <= len(player1):
            b = player1.pop(int(a) - 1)
            player1river.append(b)
            c += 1
            return c
        elif int(a) == 0:
            b = player1.remove(current_draw)
            player1river.append(b)
            c += 1
            return c
        else:
            print("Fuck You!")
            c += 99
            return c
def drawandthrow2(c):
    global call, ron
    player2.append(tiles2[c])
    a = player2.pop()
    print("2P throws " + str(a[0]))
    tmp = copy.deepcopy(player1)
    tmp.append(a)
    checkron(tmp)
    if ron == 1:
        b = input("Do you want to ron " + str(a[0]) + "?")
        if b == "yes":
            print("Ron!!!")
            c += 1000
            return c
        else:
            ron = 0
    tmp.clear()
    if richi != 2:
        checkponkan(a)
    if call == 0:
        player2river.append(a)
    c += 1
    return c
def drawandthrow3(c):
    global call, ron
    player3.append(tiles2[c])
    a = player3.pop()
    print("3P throws " + str(a[0]))
    tmp = copy.deepcopy(player1)
    tmp.append(a)
    checkron(tmp)
    if ron == 1:
        b = input("Do you want to ron " + str(a[0]) + "?")
        if b == "yes":
            print("Ron!!!")
            c += 1000
            return c
        else:
            ron = 0
    tmp.clear()
    if richi != 2:
        checkponkan(a)
    if call == 0:
        player3river.append(a)
    c += 1
    return c

# %%
# 執行單機麻將
while c < 94:
    if call == 0:
        c = drawandthrow1(c)
        if c > 1000:
            break
        if c >= 94:
            print("You lose1!")
            break
    call = 0
    c = drawandthrow2(c)
    if c > 1000:
        break
    if c >= 94:
        print("You lose2!")
        break
    if call == 0:
        c = drawandthrow3(c)
        if c > 1000:
            break
        if c >= 94:
            print("You lose3!")
print(player1_call)
player1_call.clear()
# Out:
# You draw this:pei3
# This is your hand:
# [('1m1', 0), ('4p1', 20), ('4p3', 22), ('5p2', 25), ('2s4', 51), ('3s1', 52), ('4s2', 57), ('5s1', 60), ('5s4', 63), ('nan3', 86), ('pei2', 93), ('pei3', 94), ('haku4', 99), ('hatsu2', 101)]
# Do you want to pei?yes
# You draw this:9p3
# This is your hand:
# [('1m1', 0), ('4p1', 20), ('4p3', 22), ('5p2', 25), ('9p3', 42), ('2s4', 51), ('3s1', 52), ('4s2', 57), ('5s1', 60), ('5s4', 63), ('nan3', 86), ('pei3', 94), ('haku4', 99), ('hatsu2', 101)]
# Do you want to pei?yes
# You draw this:shia2
# This is your hand:
# [('1m1', 0), ('4p1', 20), ('4p3', 22), ('5p2', 25), ('9p3', 42), ('2s4', 51), ('3s1', 52), ('4s2', 57), ('5s1', 60), ('5s4', 63), ('nan3', 86), ('shia2', 89), ('haku4', 99), ('hatsu2', 101)]
# Which one do you want to throw?14
# 2P throws 5p3
# 3P throws 7s1
# You draw this:1p2
# This is your hand:
# [('1m1', 0), ('1p2', 9), ('4p1', 20), ('4p3', 22), ('5p2', 25), ('9p3', 42), ('2s4', 51), ('3s1', 52), ('4s2', 57), ('5s1', 60), ('5s4', 63), ('nan3', 86), ('shia2', 89), ('haku4', 99)]
# Which one do you want to throw?14
# 2P throws 1s1
# 3P throws 7s2
# You draw this:ton2
# This is your hand:
# [('1m1', 0), ('1p2', 9), ('4p1', 20), ('4p3', 22), ('5p2', 25), ('9p3', 42), ('2s4', 51), ('3s1', 52), ('4s2', 57), ('5s1', 60), ('5s4', 63), ('ton2', 81), ('nan3', 86), ('shia2', 89)]
# Which one do you want to throw?14
# 2P throws pei4
# 3P throws 8s3
# You draw this:1m4
# This is your hand:
# [('1m1', 0), ('1m4', 3), ('1p2', 9), ('4p1', 20), ('4p3', 22), ('5p2', 25), ('9p3', 42), ('2s4', 51), ('3s1', 52), ('4s2', 57), ('5s1', 60), ('5s4', 63), ('ton2', 81), ('nan3', 86)]
# Which one do you want to throw?14
# 2P throws 1s4
# 3P throws haku3
# You draw this:chun1
# This is your hand:
# [('1m1', 0), ('1m4', 3), ('1p2', 9), ('4p1', 20), ('4p3', 22), ('5p2', 25), ('9p3', 42), ('2s4', 51), ('3s1', 52), ('4s2', 57), ('5s1', 60), ('5s4', 63), ('ton2', 81), ('chun1', 104)]
# Which one do you want to throw?14
# 2P throws 9m1
# 3P throws 7p3
# You draw this:nan4
# This is your hand:
# [('1m1', 0), ('1m4', 3), ('1p2', 9), ('4p1', 20), ('4p3', 22), ('5p2', 25), ('9p3', 42), ('2s4', 51), ('3s1', 52), ('4s2', 57), ('5s1', 60), ('5s4', 63), ('ton2', 81), ('nan4', 87)]
# Which one do you want to throw?14
# 2P throws 4s3
# 3P throws chun4
# You draw this:6s2
# This is your hand:
# [('1m1', 0), ('1m4', 3), ('1p2', 9), ('4p1', 20), ('4p3', 22), ('5p2', 25), ('9p3', 42), ('2s4', 51), ('3s1', 52), ('4s2', 57), ('5s1', 60), ('5s4', 63), ('6s2', 65), ('ton2', 81)]
# Which one do you want to throw?14
# 2P throws 6p1
# 3P throws 9m2
# You draw this:1m3
# This is your hand:
# [('1m1', 0), ('1m3', 2), ('1m4', 3), ('1p2', 9), ('4p1', 20), ('4p3', 22), ('5p2', 25), ('9p3', 42), ('2s4', 51), ('3s1', 52), ('4s2', 57), ('5s1', 60), ('5s4', 63), ('6s2', 65)]
# Which one do you want to throw?4
# 2P throws 6p4
# 3P throws shia3
# You draw this:5s3
# This is your hand:
# [('1m1', 0), ('1m3', 2), ('1m4', 3), ('4p1', 20), ('4p3', 22), ('5p2', 25), ('9p3', 42), ('2s4', 51), ('3s1', 52), ('4s2', 57), ('5s1', 60), ('5s3', 62), ('5s4', 63), ('6s2', 65)]
# Which one do you want to throw?7
# 2P throws 3p2
# 3P throws 7p1
# You draw this:2p4
# This is your hand:
# [('1m1', 0), ('1m3', 2), ('1m4', 3), ('2p4', 15), ('4p1', 20), ('4p3', 22), ('5p2', 25), ('2s4', 51), ('3s1', 52), ('4s2', 57), ('5s1', 60), ('5s3', 62), ('5s4', 63), ('6s2', 65)]
# Which one do you want to throw?4
# 2P throws 2s3
# 3P throws 8p3
# You draw this:haku2
# This is your hand:
# [('1m1', 0), ('1m3', 2), ('1m4', 3), ('4p1', 20), ('4p3', 22), ('5p2', 25), ('2s4', 51), ('3s1', 52), ('4s2', 57), ('5s1', 60), ('5s3', 62), ('5s4', 63), ('6s2', 65), ('haku2', 97)]
# Which one do you want to throw?0
# 2P throws 4s1
# 3P throws 9m4
# You draw this:3p3
# Do you want to richi?no
# This is your hand:
# [('1m1', 0), ('1m3', 2), ('1m4', 3), ('3p3', 18), ('4p1', 20), ('4p3', 22), ('5p2', 25), ('2s4', 51), ('3s1', 52), ('4s2', 57), ('5s1', 60), ('5s3', 62), ('5s4', 63), ('6s2', 65)]
# Which one do you want to throw?5
# 2P throws hatsu1
# 3P throws 4p2
# You draw this:4s4
# Do you want to tsumo?no
# Do you want to richi?yes
# 1P Richi!!!
# This is your hand:
# [('1m1', 0), ('1m3', 2), ('1m4', 3), ('3p3', 18), ('4p3', 22), ('5p2', 25), ('2s4', 51), ('3s1', 52), ('4s2', 57), ('4s4', 59), ('5s1', 60), ('5s3', 62), ('5s4', 63), ('6s2', 65)]
# Which one do you want to throw?9
# 2P throws pei1
# 3P throws chun2
# You draw this:3p1
# 2P throws 8s1
# 3P throws 8s4
# You draw this:7p2
# 2P throws chun3
# 3P throws 5p1
# You draw this:2p2
# 2P throws 5p4
# 3P throws 3p4
# You draw this:1p1
# 2P throws hatsu3
# 3P throws 4p4
# You draw this:nan1
# 2P throws 9s2
# 3P throws 6s3
# Do you want to ron 6s3?yes
# Ron!!!
# []

# %%
# pygame test
import pygame

pygame.init()
width, height = 640, 480
screen=pygame.display.set_mode((width, height))
playerpos=[100,100]
table_color = [0, 100, 0]
screen.fill(table_color)

player = pygame.image.load("resources/images/hatsu.png")
player2 = pygame.image.load("resources/images/front.png")

pygame.mixer.music.load('resources/audio/moonlight.wav')
pygame.mixer.music.play(-1, 0.0)
pygame.mixer.music.set_volume(0.25)

while 1:
    screen.blit(player2, playerpos) 
    screen.blit(player, playerpos)
    pygame.display.flip()
    for event in pygame.event.get():
        if event.type==pygame.QUIT:
            pygame.quit()
            exit(0)
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            pygame.quit()
            exit(0)
    pygame.display.flip()
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-19-63fd949fd9a7> in <module>()
#      24             pygame.quit()
#      25             exit(0)
# ---> 26     for event in pygame.event.get():
#      27         if event.type == pygame.QUIT:
#      28             pygame.quit()
#
# error: video system not initialized
