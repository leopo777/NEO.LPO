# %%
# 找所有可能雀頭
def findpair(x):
    tmp = []
    pair = []
    setx = set(x)
    for a in setx:
        for b in range(len(x)):
            if x[b] == a:
                tmp.append(a)
        if len(tmp) >= 2:
            pair.append(tmp[0])
            tmp.clear()
        else:
            tmp.clear()
    return pair

# %%
# 測最小牌能否找到順子
def checkflush(x):
    global GG
    if x:
        if x[0] + 1 in x:
            tmp1 = x[0] + 1
            if x[0] + 2 in x:
                tmp2 = x[0] + 2
                x.remove(x[0])
                x.remove(tmp1)
                x.remove(tmp2)
    return x

# %%
# 測最小牌能否找到暗刻
def checktriple(x):
    global tri
    tmp = []
    for a in range(len(x)):
        if x[a] == x[0]:
            tmp.append(x[0])
    if len(tmp) >= 3:
        x.remove(tmp[0])
        x.remove(tmp[0])
        x.remove(tmp[0])
        tri = 1
    return x

# %%
# 測條子跟筒子是否會消光光
def roncheck(x):
    tri = 0
    win = 0
    count = 0
    while x:
        checktriple(x)
        if not x:
            win = 1
            return x
        if tri == 1:
            tri = 0
            continue
        checkflush(x)
        count += 1
        if not x:
            win = 1
            return x
        if count > 5:
            break
    if win == 0:
        return x

# %%
# 測是不是全部都暗刻，萬子跟字牌專用
def checktriple2(x):
    tmp = []
    for a in x:
        for b in range(len(x)):
            if a == x[b]:
                tmp.append(a)
        if len(tmp) == 3:
            x.remove(tmp[0])
            x.remove(tmp[0])
            x.remove(tmp[0])
        else:
            tmp.clear()
    return x

# %%
# 胡牌檢查
import copy
def checkron(x):
    global ron
    GG = 0
    check = []
    checkm = []
    checkp = []
    checks = []
    checky = []
    for i in x:
        check.append(int(i[1] // 4))
    for i in check:
        if i == 0:
            checkm.append(1)
        elif i == 1:
            checkm.append(9)
        elif 2 <= i <= 10:
            checkp.append(int(i - 1))
        elif 11 <= i <= 19:
            checks.append(int(i - 10))
        else:
            checky.append(int(i - 19))
    mpair = findpair(checkm)
    ppair = findpair(checkp)
    spair = findpair(checks)
    ypair = findpair(checky)
    for x in mpair:
        mtmp = copy.deepcopy(checkm)
        ptmp = copy.deepcopy(checkp)
        stmp = copy.deepcopy(checks)
        ytmp = copy.deepcopy(checky)
        mtmp.remove(x)
        mtmp.remove(x)
        checktriple2(mtmp)
        if mtmp:
            continue
        roncheck(ptmp)
        if ptmp:
            continue
        roncheck(stmp)
        if stmp:
            continue
        checktriple2(ytmp)
        if ytmp:
            continue
        else:
            ron = 1
            return ron
    for x in ppair:
        mtmp2 = copy.deepcopy(checkm)
        ptmp2 = copy.deepcopy(checkp)
        stmp2 = copy.deepcopy(checks)
        ytmp2 = copy.deepcopy(checky)
        ptmp2.remove(x)
        ptmp2.remove(x)
        checktriple2(mtmp2)
        if mtmp2:
            continue
        roncheck(ptmp2)
        if ptmp2:
            continue
        roncheck(stmp2)
        if stmp2:
            continue
        checktriple2(ytmp2)
        if ytmp2:
            continue
        else:
            ron = 1
            return ron
    for x in spair:
        mtmp3 = copy.deepcopy(checkm)
        ptmp3 = copy.deepcopy(checkp)
        stmp3 = copy.deepcopy(checks)
        ytmp3 = copy.deepcopy(checky)
        stmp3.remove(x)
        stmp3.remove(x)
        checktriple2(mtmp3)
        if mtmp3:
            continue
        roncheck(ptmp3)
        if ptmp3:
            continue
        roncheck(stmp3)
        if stmp3:
            continue
        checktriple2(ytmp3)
        if ytmp3:
            continue
        else:
            ron = 1
            return ron
    for x in ypair:
        mtmp4 = copy.deepcopy(checkm)
        ptmp4 = copy.deepcopy(checkp)
        stmp4 = copy.deepcopy(checks)
        ytmp4 = copy.deepcopy(checky)
        ytmp4.remove(x)
        ytmp4.remove(x)
        checktriple2(mtmp4)
        if mtmp4:
            continue
        roncheck(ptmp4)
        if ptmp4:
            continue
        roncheck(stmp4)
        if stmp4:
            continue
        checktriple2(ytmp4)
        if ytmp4:
            continue
        else:
            ron = 1
            return ron
    return ron

# %%
# 叫牌檢查
def checkponkan(x):
    global player1, c, call, player1_call
    tmp1 = 0
    lst1 = []
    a = x[1] // 4
    for i in range(len(player1)):
        if player1[i][1] // 4 == a:
            tmp1 += 1
            lst1.append(player1[i])
    if tmp1 == 2:
        print("This is your hand:\n" + str(player1))
        b = input("Do you want to pon " + str(x[0]) + "?")
        if b == "yes":
            call = 1
            player1_call.append(lst1[0])
            player1.remove(lst1[0])
            player1.remove(lst1[1])
            print("This is your hand:\n" + str(player1))
            e = input("Which one do you want to throw?")
            if 0 <= int(e) - 1 <= len(player1):
                d = player1.pop(int(e) - 1)
                player1river.append(d)
                return
    elif tmp1 == 3:
        print("This is your hand:\n" + str(player1))
        d = input("Do you want to pon or kan " + str(x[0]) + "?")
        if d == "kan":
            call = 1
            player1.remove(lst1[0])
            player1.remove(lst1[1])
            player1.remove(lst1[2])
            print("You draw this:" + str(tiles2[-1]))
            player1.append(tiles2[-1])
            player1 = sorted(player1, key=lambda tup:(tup[1]))
            tiles2.pop()
            print("This is your hand:\n" + str(player1))
            e = input("Which one do you want to throw?")
            if 0 <= int(e) - 1 <= len(player1):
                d = player1.pop(int(e) - 1)
                player1river.append(d)
                c += 1
                return
        elif d == "pon":
            call = 1
            player1_call.append(lst1[0])
            player1.remove(lst1[0])
            player1.remove(lst1[1])
            print("This is your hand:\n" + str(player1))
            e = input("Which one do you want to throw?")
            if 0 <= int(e) - 1 <= len(player1):
                d = player1.pop(int(e) - 1)
                player1river.append(d)
                return
    return

# %%
# 暗槓 or 加槓檢查
def checkkan(x):
    global player1, c, player1_call
    tmp1 = 0
    lst1 = []
    a = x[1] // 4
    b = x[0]
    if b in player1_call:
        d = input("Do you want to kan " + str(x[0]) + "?")
        if d == "yes":
            print("You draw this:" + str(tiles2[-1]))
            player1.append(tiles2[-1])
            player1 = sorted(player1, key=lambda tup:(tup[1]))
            tiles2.pop()
            print("This is your hand:\n" + str(player1))
            e = input("Which one do you want to throw?")
            if 0 <= int(e) - 1 <= len(player1):
                d = player1.pop(int(e) - 1)
                player1river.append(d)
                c += 1
                return
    for i in range(len(player1)):
        if player1[i][1] // 4 == a:
            tmp1 += 1
            lst1.append(player1[i])
    if tmp1 == 3:
        d = input("Do you want to kan " + str(x[0]) + "?")
        if d == "yes":
            player1.remove(lst1[0])
            player1.remove(lst1[1])
            player1.remove(lst1[2])
            print("You draw this:" + str(tiles2[-1]))
            player1.append(tiles2[-1])
            player1 = sorted(player1, key=lambda tup:(tup[1]))
            tiles2.pop()
            print("This is your hand:\n" + str(player1))
            e = input("Which one do you want to throw?")
            if 0 <= int(e) - 1 <= len(player1):
                d = player1.pop(int(e) - 1)
                player1river.append(d)
                c += 1
                return

# %%
# 拔北檢查
def checkpei():
    global player1, c
    for i in range(len(player1)):
        if player1[i][1] // 4 == 23:
            print("This is your hand:\n" + str(player1))
            a = input("Do you want to pei?")
            if a == "yes":
                player1.remove(player1[i])
                print("You draw this:" + str(tiles2[-1]))
                player1.append(tiles2[-1])
                player1 = sorted(player1, key=lambda tup:(tup[1]))
                tiles2.pop()
                c += 1

# %%
# 生成麻將牌
tiles = []
ping = []
souzu = []
onenine = []
c = 0
for y in range(4):
    onenine.append(('1m' + str(y+1), c))
    c += 1
for y in range(4):
    onenine.append(('9m' + str(y+1), c))
    c += 1
for x in range(9):
    for y in range(4):
        ping.append((str(x + 1) + 'p' + str(y+1), c))
        c += 1
for x in range(9):
    for y in range(4):
        souzu.append((str(x + 1) + 's' + str(y+1), c))
        c += 1
for y in range(4):
    onenine.append(('ton' + str(y+1), c))
    c += 1
for y in range(4):
    onenine.append(('nan' + str(y+1), c))
    c += 1
for y in range(4):
    onenine.append(('shia' + str(y+1), c))
    c += 1
for y in range(4):
    onenine.append(('pei' + str(y+1), c))
    c += 1
for y in range(4):
    onenine.append(('haku' + str(y+1), c))
    c += 1
for y in range(4):
    onenine.append(('hatsu' + str(y+1), c))
    c += 1
for y in range(4):
    onenine.append(('chun' + str(y+1), c))
    c += 1
tiles.append(ping)
tiles.append(souzu)
tiles.append(onenine)

# %%
# 整理成一個大list
tiles2 = []
for x in range(3):
    for y in range(len(tiles[x])):
        tiles2.append(tiles[x][y])

# %%
# 洗牌
import random
random.shuffle(tiles2)

# %%
# 發牌，雖然不是正統發法
player1 = []
player2 = []
player3 = []
player1river = []
player2river = []
player3river = []
player1_call = []
c = 0
call = 0
ron = 0
for x in range(39):
    if x % 3 == 0:
        player1.append(tiles2[x])
        c += 1
    elif x % 3 == 1:
        player2.append(tiles2[x])
        c += 1
    else:
        player3.append(tiles2[x])
        c += 1
player1 = sorted(player1, key=lambda tup:(tup[1]))
player2 = sorted(player2, key=lambda tup:(tup[1]))
player3 = sorted(player3, key=lambda tup:(tup[1]))

# %%
# 摸牌 and 打牌
def drawandthrow1(c):
    global player1
    print("You draw this:" + str(tiles2[c]))
    player1.append(tiles2[c])
    player1 = sorted(player1, key=lambda tup:(tup[1]))
    checkpei()
    checkkan(tiles2[c])
    checkron(player1)
    if ron == 1:
        b = input("Do you want to tsumo?")
        if b == "yes":
            print("Tsumo!!!")
            c += 1000
            return c
    print("This is your hand:\n" + str(player1))
    a = input("Which one do you want to throw?")
    if 0 <= int(a) - 1 <= len(player1):
        b = player1.pop(int(a) - 1)
        player1river.append(b)
        c += 1
        return c
    elif int(a) == 0:
        b = player1.remove(tiles2[c])
        player1river.append(b)
        c += 1
        return c
    else:
        print("Fuck You!")
        c += 99
        return c
def drawandthrow2(c):
    global call, ron
    player2.append(tiles2[c])
    a = player2.pop()
    print("2P throws " + str(a))
    tmp = copy.deepcopy(player1)
    tmp.append(a)
    checkron(tmp)
    if ron == 1:
        b = input("Do you want to ron " + str(a[0]) + "?")
        if b == "yes":
            print("Ron!!!")
            c += 1000
            return c
    tmp.clear()
    checkponkan(a)
    if call == 0:
        player2river.append(a)
    c += 1
    return c
def drawandthrow3(c):
    global call, ron
    player3.append(tiles2[c])
    a = player3.pop()
    print("3P throws " + str(a))
    tmp = copy.deepcopy(player1)
    tmp.append(a)
    checkron(tmp)
    if ron == 1:
        b = input("Do you want to ron " + str(a[0]) + "?")
        if b == "yes":
            print("Ron!!!")
            c += 1000
            return c
    tmp.clear()
    checkponkan(a)
    if call == 0:
        player3river.append(a)
    c += 1
    return c

# %%
# 執行單機麻將
while c < 94:
    if call == 0:
        c = drawandthrow1(c)
        if c > 1000:
            break
        if c >= 94:
            print("You lose1!")
            break
    call = 0
    c = drawandthrow2(c)
    if c > 1000:
        break
    if c >= 94:
        print("You lose2!")
        break
    if call == 0:
        c = drawandthrow3(c)
        if c > 1000:
            break
        if c >= 94:
            print("You lose3!")
print(player1_call)
player1_call.clear()
# Out:
# You draw this:('4p1', 20)
# This is your hand:
# [('1p3', 10), ('3p2', 17), ('3p4', 19), ('4p1', 20), ('8p1', 36), ('9p3', 42), ('1s3', 46), ('3s4', 55), ('8s1', 72), ('ton3', 82), ('shia2', 89), ('haku4', 99), ('hatsu1', 100), ('chun2', 105)]
# Which one do you want to throw?14
# 2P throws ('nan2', 85)
# 3P throws ('1p2', 9)
# You draw this:('5p4', 27)
# This is your hand:
# [('1p3', 10), ('3p2', 17), ('3p4', 19), ('4p1', 20), ('5p4', 27), ('8p1', 36), ('9p3', 42), ('1s3', 46), ('3s4', 55), ('8s1', 72), ('ton3', 82), ('shia2', 89), ('haku4', 99), ('hatsu1', 100)]
# Which one do you want to throw?14
# 2P throws ('pei1', 92)
# 3P throws ('nan4', 87)
# You draw this:('2p1', 12)
# This is your hand:
# [('1p3', 10), ('2p1', 12), ('3p2', 17), ('3p4', 19), ('4p1', 20), ('5p4', 27), ('8p1', 36), ('9p3', 42), ('1s3', 46), ('3s4', 55), ('8s1', 72), ('ton3', 82), ('shia2', 89), ('haku4', 99)]
# Which one do you want to throw?14
# 2P throws ('8p3', 38)
# 3P throws ('shia1', 88)
# You draw this:('1s4', 47)
# This is your hand:
# [('1p3', 10), ('2p1', 12), ('3p2', 17), ('3p4', 19), ('4p1', 20), ('5p4', 27), ('8p1', 36), ('9p3', 42), ('1s3', 46), ('1s4', 47), ('3s4', 55), ('8s1', 72), ('ton3', 82), ('shia2', 89)]
# Which one do you want to throw?14
# 2P throws ('4p2', 21)
# 3P throws ('5p2', 25)
# You draw this:('1m2', 1)
# This is your hand:
# [('1m2', 1), ('1p3', 10), ('2p1', 12), ('3p2', 17), ('3p4', 19), ('4p1', 20), ('5p4', 27), ('8p1', 36), ('9p3', 42), ('1s3', 46), ('1s4', 47), ('3s4', 55), ('8s1', 72), ('ton3', 82)]
# Which one do you want to throw?14
# 2P throws ('6p2', 29)
# 3P throws ('2s1', 48)
# You draw this:('9m3', 6)
# This is your hand:
# [('1m2', 1), ('9m3', 6), ('1p3', 10), ('2p1', 12), ('3p2', 17), ('3p4', 19), ('4p1', 20), ('5p4', 27), ('8p1', 36), ('9p3', 42), ('1s3', 46), ('1s4', 47), ('3s4', 55), ('8s1', 72)]
# Which one do you want to throw?1
# 2P throws ('3p1', 16)
# This is your hand:
# [('9m3', 6), ('1p3', 10), ('2p1', 12), ('3p2', 17), ('3p4', 19), ('4p1', 20), ('5p4', 27), ('8p1', 36), ('9p3', 42), ('1s3', 46), ('1s4', 47), ('3s4', 55), ('8s1', 72)]
# Do you want to pon 3p1?1
# 3P throws ('6p1', 28)
# You draw this:('nan1', 84)
# This is your hand:
# [('9m3', 6), ('1p3', 10), ('2p1', 12), ('3p2', 17), ('3p4', 19), ('4p1', 20), ('5p4', 27), ('8p1', 36), ('9p3', 42), ('1s3', 46), ('1s4', 47), ('3s4', 55), ('8s1', 72), ('nan1', 84)]
# Which one do you want to throw?14
# 2P throws ('3s2', 53)
# 3P throws ('5s3', 62)
# You draw this:('6s1', 64)
# This is your hand:
# [('9m3', 6), ('1p3', 10), ('2p1', 12), ('3p2', 17), ('3p4', 19), ('4p1', 20), ('5p4', 27), ('8p1', 36), ('9p3', 42), ('1s3', 46), ('1s4', 47), ('3s4', 55), ('6s1', 64), ('8s1', 72)]
# Which one do you want to throw?1
# 2P throws ('8s2', 73)
# 3P throws ('1s1', 44)
# This is your hand:
# [('1p3', 10), ('2p1', 12), ('3p2', 17), ('3p4', 19), ('4p1', 20), ('5p4', 27), ('8p1', 36), ('9p3', 42), ('1s3', 46), ('1s4', 47), ('3s4', 55), ('6s1', 64), ('8s1', 72)]
# Do you want to pon 1s1?yes
# This is your hand:
# [('1p3', 10), ('2p1', 12), ('3p2', 17), ('3p4', 19), ('4p1', 20), ('5p4', 27), ('8p1', 36), ('9p3', 42), ('3s4', 55), ('6s1', 64), ('8s1', 72)]
# Which one do you want to throw?9
# 2P throws ('4s1', 56)
# 3P throws ('8p2', 37)
# You draw this:('ton2', 81)
# This is your hand:
# [('1p3', 10), ('2p1', 12), ('3p2', 17), ('3p4', 19), ('4p1', 20), ('5p4', 27), ('8p1', 36), ('9p3', 42), ('6s1', 64), ('8s1', 72), ('ton2', 81)]
# Which one do you want to throw?11
# 2P throws ('4p4', 23)
# 3P throws ('3s1', 52)
# You draw this:('1m3', 2)
# This is your hand:
# [('1m3', 2), ('1p3', 10), ('2p1', 12), ('3p2', 17), ('3p4', 19), ('4p1', 20), ('5p4', 27), ('8p1', 36), ('9p3', 42), ('6s1', 64), ('8s1', 72)]
# Which one do you want to throw?1
# 2P throws ('8p4', 39)
# 3P throws ('1p4', 11)
# You draw this:('pei3', 94)
# This is your hand:
# [('1p3', 10), ('2p1', 12), ('3p2', 17), ('3p4', 19), ('4p1', 20), ('5p4', 27), ('8p1', 36), ('9p3', 42), ('6s1', 64), ('8s1', 72), ('pei3', 94)]
# Do you want to pei?yes
# You draw this:('4s3', 58)
# This is your hand:
# [('1p3', 10), ('2p1', 12), ('3p2', 17), ('3p4', 19), ('4p1', 20), ('5p4', 27), ('8p1', 36), ('9p3', 42), ('4s3', 58), ('6s1', 64), ('8s1', 72)]
# Which one do you want to throw?11
# 2P throws ('9p2', 41)
# 3P throws ('1m4', 3)
# You draw this:('5p3', 26)
# This is your hand:
# [('1p3', 10), ('2p1', 12), ('3p2', 17), ('3p4', 19), ('4p1', 20), ('5p3', 26), ('5p4', 27), ('8p1', 36), ('9p3', 42), ('4s3', 58), ('6s1', 64)]
# Which one do you want to throw?11
# 2P throws ('9p1', 40)
# 3P throws ('7s1', 68)
# You draw this:('7p4', 35)
# This is your hand:
# [('1p3', 10), ('2p1', 12), ('3p2', 17), ('3p4', 19), ('4p1', 20), ('5p3', 26), ('5p4', 27), ('7p4', 35), ('8p1', 36), ('9p3', 42), ('4s3', 58)]
# Which one do you want to throw?11
# 2P throws ('2p3', 14)
# 3P throws ('1s2', 45)
# You draw this:('9m1', 4)
# This is your hand:
# [('9m1', 4), ('1p3', 10), ('2p1', 12), ('3p2', 17), ('3p4', 19), ('4p1', 20), ('5p3', 26), ('5p4', 27), ('7p4', 35), ('8p1', 36), ('9p3', 42)]
# Which one do you want to throw?0
# 2P throws ('4p3', 22)
# 3P throws ('4s4', 59)
# You draw this:('5s4', 63)
# This is your hand:
# [('1p3', 10), ('2p1', 12), ('3p2', 17), ('3p4', 19), ('4p1', 20), ('5p3', 26), ('5p4', 27), ('7p4', 35), ('8p1', 36), ('9p3', 42), ('5s4', 63)]
# Which one do you want to throw?0
# 2P throws ('6s3', 66)
# 3P throws ('pei2', 93)
# You draw this:('ton1', 80)
# This is your hand:
# [('1p3', 10), ('2p1', 12), ('3p2', 17), ('3p4', 19), ('4p1', 20), ('5p3', 26), ('5p4', 27), ('7p4', 35), ('8p1', 36), ('9p3', 42), ('ton1', 80)]
# Which one do you want to throw?0
# 2P throws ('8s3', 74)
# 3P throws ('chun4', 107)
# You draw this:('9m4', 7)
# This is your hand:
# [('9m4', 7), ('1p3', 10), ('2p1', 12), ('3p2', 17), ('3p4', 19), ('4p1', 20), ('5p3', 26), ('5p4', 27), ('7p4', 35), ('8p1', 36), ('9p3', 42)]
# Which one do you want to throw?0
# 2P throws ('6p3', 30)
# 3P throws ('9s3', 78)
# You draw this:('hatsu2', 101)
# This is your hand:
# [('1p3', 10), ('2p1', 12), ('3p2', 17), ('3p4', 19), ('4p1', 20), ('5p3', 26), ('5p4', 27), ('7p4', 35), ('8p1', 36), ('9p3', 42), ('hatsu2', 101)]
# Which one do you want to throw?0
# 2P throws ('haku1', 96)
# You lose2!
# [('1s3', 46)]

# %%
# pygame test
import pygame

pygame.init()
width, height = 640, 480
screen=pygame.display.set_mode((width, height))
playerpos=[100,100]
table_color = [0, 100, 0]
screen.fill(table_color)

player = pygame.image.load("resources/images/hatsu.png")
player2 = pygame.image.load("resources/images/front.png")

pygame.mixer.music.load('resources/audio/moonlight.wav')
pygame.mixer.music.play(-1, 0.0)
pygame.mixer.music.set_volume(0.25)

while 1:
    screen.blit(player2, playerpos) 
    screen.blit(player, playerpos)
    pygame.display.flip()
    for event in pygame.event.get():
        if event.type==pygame.QUIT:
            pygame.quit()
            exit(0)
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            pygame.quit()
            exit(0)
    pygame.display.flip()
